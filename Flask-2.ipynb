# %% [markdown]
# ## Q1. Explain GET and POST methods.

# %% [markdown]
# GET is used to request data from specified resource.The query
# string is sent with the url in GET request.GET request are cached ,GET request has length restrictions.

# %% [markdown]
# POST method is used to sebd data to the server .Data send in the post
# are send in the body .Post request are never cached,POST request has no
# length restrictions

# %% [markdown]
# ## Q2. Why is request used in Flask?

# %% [markdown]
# Request object in Flask contains all the data sent from client to server
# ,all the data can be accesed at server side using different method types .

# %% [markdown]
# ## Q3. Why is redirect() used in Flask?

# %% [markdown]
# Flask class has a redirect() function. When called, it returns a response object and redirects the user to another target location with specified status code.

# %% [markdown]
# ## Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# Templates in flaskk contains the static files and palceholder for
# dynamic data as well

# %% [markdown]
# render_template function in flask  is used to render the html file in browser

# %% [markdown]
# ## Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %% [markdown]
# ![Screenshot%202023-03-05%20at%204.46.22%20PM.png](attachment:Screenshot%202023-03-05%20at%204.46.22%20PM.png)Screenshot 2023-03-05 at 4.46.22 PM
